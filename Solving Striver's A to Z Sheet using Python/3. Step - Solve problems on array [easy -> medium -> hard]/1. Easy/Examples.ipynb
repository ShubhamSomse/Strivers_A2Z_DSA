# %%
def largest_ele(arr):
    largest = float('-inf')
    for i in range(len(arr)):
        if arr[i] > largest:
            largest = arr[i]
    return largest
    
arr = [2, 5, 1, 3, 0]

largest_ele(arr)

# %%
def largest_ele(arr):
    largest = float('inf')
    for i in range(len(arr)):
        if arr[i] < largest:
            largest = arr[i]
    return largest
    
arr = [2, 5, 1, 3, 0, -1]

largest_ele(arr)
