# %% [markdown]
# Section	Pattern	Problems (LeetCode IDs & Names)	Status	Difficulty Focus	Notes / Mistakes / Edge Cases
# I. Two Pointers	Converging (Sorted Array Target Sum)	11 Container With Most Water, 15 3Sum, 16 3Sum Closest, 18 4Sum, 167 Two Sum II, 349 Intersection of Two Arrays, 881 Boats to Save People, 977 Squares of a Sorted Array, 259 3Sum Smaller		Medium–Hard
# 	Fast & Slow (Cycle Detection)	141 Linked List Cycle, 202 Happy Number, 287 Find the Duplicate Number, 392 Is Subsequence		Easy–Medium
# 	Fixed Separation (Nth Node from End)	19 Remove Nth Node From End, 876 Middle of the Linked List, 2095 Delete the Middle Node		Easy–Medium
# 	In-place Array Modification	26 Remove Duplicates, 27 Remove Element, 75 Sort Colors, 80 Remove Duplicates II, 283 Move Zeroes, 443 String Compression, 905 Sort Array By Parity	18-Dec. Probl 75 done	Easy–Medium
# 	String Comparison / Cleanup	844 Backspace String Compare, 1598 Crawler Log Folder, 2390 Removing Stars From a String		Easy–Medium
# 	Expand From Center (Palindromes)	5 Longest Palindromic Substring, 647 Palindromic Substrings		Medium

# %%
# LeetCode 75. Sort Colors( Dutch Flag Pattern)

class Solution:
    def sortColors(self, nums: List[int]) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        low = mid = 0
        high = len(nums) - 1
        while mid <= high:
            if nums[mid] == 0:
                nums[low], nums[mid] = nums[mid], nums[low]
                low += 1
                mid += 1
            elif nums[mid] == 1:
                mid += 1
            else:
                nums[mid], nums[high] = nums[high], nums[mid]
                high -= 1
