# %%
# %python
print("Hello_world")

# %%
x=5
print(x)

# %%
x= 5
y= 2
print("sum of x and y is=", x+y)

# %%
print('shubham',end ='\n')
print('somse')

# %%
print('shubham', end =' ')
print('somse')
