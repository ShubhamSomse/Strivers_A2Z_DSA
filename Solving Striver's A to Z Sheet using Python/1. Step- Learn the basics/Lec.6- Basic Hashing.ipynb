# %%
arr = [10,5,27,5,5,10,10,10,25,5]

print(arr)
d={}

for item in arr:
    d[item] = d.get(item,0) + 1
print(d)

# %%
arr = [10,5,27,5,5,10,10,10,25,5]

print(arr)

d = {}

for item in arr:
    d[item] = d.get(item,0) + 1

print(d.items())

maxCount = 0
maxValue = -1

minCount = 10000000
# or 
# minCount = float('inf')
minValue = -1
for key,count in d.items():
    if maxCount < count:
        maxValue = key
        maxCount = count

for key, count in d.items():
    if minCount > count:
        minValue = key
        minCount = count

print(maxValue, maxCount)
print(minValue, minCount)
